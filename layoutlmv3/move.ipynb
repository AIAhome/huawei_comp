# %%
import moxing as mox                # 这个库不用装，在modelarts的notebook里可直接使用

obs_file_path = "obs://obs桶名称/data/train.tgz"     # 以obs://开头，第一级目录为桶名称，后面为桶内具体文件的路径
local_save_path = "./model/train.tgz"                         # 本地路径，表示要拷贝到哪里，一定要具体到文件名，不能只写到目录名
mox.file.copy(obs_file_path, local_save_path)

# %%
# mox.file.copy()  还可以将本地文件拷贝到OBS内哦，调换一下路径顺序就好了
# !tar zxf ./model/train.tgz  # 请不要用zxvf解压参数，这样输出过多会导致notebook卡死

# !mkdir data
# !mv train data/
# Out:
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.FinderInfo'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# ...

# %%
import moxing as mox

# csig是我的桶名，各位用自己实际的桶名字
mox.file.make_dirs('obs://obs桶名称/layoutlmv3-fine-tune/')

# 下面这个函数在使用时，目标路径中一定要指明粘贴后的文件名称，比如此例必须写到obs://csig/my_model/model，而不能只写obs://csig/my_model/
mox.file.copy_parallel('model', 'obs://obs桶名称/layoutlmv3-fine-tune/model')

# # 请根据实际情况修改模型路径
# local_model_path="saved/models/PICK_Default/test_0709_153058/model_best.pth"

# # 同上，目标路径一定要写详细的文件名，不要只写一个文件夹位置就结束。
# mox.file.copy(local_model_path,"obs://obs桶名称/my_model/model/model_best.pth")
